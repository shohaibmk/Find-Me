# %%
pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_12_0_x86_64.whl.metadata (20 kB)
# Collecting numpy>=1.17.0 (from opencv-contrib-python)
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_x86_64.whl.metadata (60 kB)
# Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_12_0_x86_64.whl (66.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 MB 45.5 MB/s eta 0:00:0000:0100:01
# Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 52.7 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-contrib-python
# Successfully installed numpy-2.0.2 opencv-contrib-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 as cv

# %%
image = cv.imread('shelves.jpg')
# cv.imshow('shelves',img)
original_shape = image.shape[:2] #dimension of the image H x W
# cv.waitKey(0)
# blob = cv.dnn.blobFromImage(image, scalefactor=1/255.0, size=(input_size, input_size),mean=(0, 0, 0), swapRB=True, crop=False)
original_shape
# blob
# Out:
# (1200, 1200)

# %%
def resizedVideo(image,scale):
    height = int(image.shape[0] * scale)
    width = int(image.shape[1] * scale)
    dimension = (width,height)
    return cv.resize(image,dimension,interpolation = cv.INTER_AREA )

cap = cv.VideoCapture(0)
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
 
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    # Our operations on the frame come here
    print(frame.shape[:2])
    frame = resizedVideo(frame,0.1)
    print(frame.shape[:2])


    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    # Display the resulting frame
    cv.imshow('frame', gray)
    if cv.waitKey(1) == ord('q'):
        break
 
# When everything done, release the capture
cap.release()
cv.destroyAllWindows()
# Out:
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
# (720, 1280)
# (360, 640)
